# %%
# Colab: mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### **Step 1: Initial cleansing**

# %%
# load pandas package and data
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Data/food_wishes_from2012.csv')
# check what the data looks like
df.head(3)
# Out:
#    Unnamed: 0     video_id                                        video_title  \
# 0           0  CQPLo8hECWg  Twice Baked Potatoes -- How to Make Fancy Stuf...
# 1           1  TsrTU3CJn2c  Irish Shepherd's Pie - Classic Shepherd Pie fo...
# 2           2  wRtGM3f-UBc             How to Flip Food in a Pan Like a Chef!
#
#   upload_date  view_count  like_count  comment_count
# 0  2012-12-15     4194592       47213           1950
# 1  2012-03-05     2730866       44230           2843
# 2  2012-10-04     2764323       17837           1382

# %%
# looks like there's an unwanted column at the very start
# need to remove it
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
# check the data types of columns
df.dtypes
# Out:
# video_id         object
# video_title      object
# upload_date      object
# view_count        int64
# like_count        int64
# comment_count     int64
# dtype: object

# %%
# the 'upload date' coulum should be in 'datetime' format but is currently showing as 'object'
# need to parse it to the correct format
df['upload_date'] = pd.to_datetime(df['upload_date'], format='%Y-%m-%d')

# %%
# also would be nice to single out the year, month , year-month and day only for finer analyses
df['upload_year'] = df['upload_date'].dt.year
df['upload_month'] = df['upload_date'].dt.month
df['upload_day'] = df['upload_date'].dt.day
df['upload_yearmonth'] = df['upload_date'].dt.to_period('M')

# %%
# check if there are any duplicate records in this dataframe
if df.shape[0] - len(df['video_id'].unique()) > 0:
    print('you have duplicates')
else:
    print('you don\'t have duplicates')
# Out:
# you have duplicates

# %%
# looks like there are duplicates
# now need to see what the duplicate records look like
df['duplicates'] = df['video_id'].duplicated(keep=False)
duplicates = df[df['duplicates'] == True]
print(f'there are {duplicates.shape[0]} records in the duplicates dataframe')
duplicates.groupby(duplicates.columns.values[0]).count()
# Out:
# there are 28 records in the duplicates dataframe
#              video_title  upload_date  view_count  like_count  comment_count  \
# video_id
# 4i-blr330n4            2            2           2           2              2
# 8SLbT652IiQ            2            2           2           2              2
# DE8EnTymPso            2            2           2           2              2
# EVuiTbde80k            2            2           2           2              2
# KHxlKnIS7pY            2            2           2           2              2
# RCqFYhip2Ys            2            2           2           2              2
# WYjsqeLHS14            2            2           2           2              2
# dZ_3xKZMOec            2            2           2           2              2
# dg-Wd3dNp6Q            2            2           2           2              2
# hHYmOefRNLk            2            2           2           2              2
# hpOWaXzVdPg            2            2           2           2              2
# lbXw1uRlkeY            2            2           2           2              2
# nPupiqnRh-A            2            2           2           2              2
# soFt2tL780M            2            2           2           2              2
#
#              upload_year  upload_month  upload_day  upload_yearmonth  \
# video_id
# 4i-blr330n4            2             2           2                 2
# 8SLbT652IiQ            2             2           2                 2
# DE8EnTymPso            2             2           2                 2
# EVuiTbde80k            2             2           2                 2
# KHxlKnIS7pY            2             2           2                 2
# RCqFYhip2Ys            2             2           2                 2
# WYjsqeLHS14            2             2           2                 2
# dZ_3xKZMOec            2             2           2                 2
# dg-Wd3dNp6Q            2             2           2                 2
# hHYmOefRNLk            2             2           2                 2
# hpOWaXzVdPg            2             2           2                 2
# lbXw1uRlkeY            2             2           2                 2
# nPupiqnRh-A            2             2           2                 2
# soFt2tL780M            2             2           2                 2
#
#              duplicates
# video_id
# 4i-blr330n4           2
# 8SLbT652IiQ           2
# DE8EnTymPso           2
# EVuiTbde80k           2
# KHxlKnIS7pY           2
# RCqFYhip2Ys           2
# WYjsqeLHS14           2
# dZ_3xKZMOec           2
# dg-Wd3dNp6Q           2
# hHYmOefRNLk           2
# hpOWaXzVdPg           2
# lbXw1uRlkeY           2
# nPupiqnRh-A           2
# soFt2tL780M           2

# %%
# well, looks like some how the API queries gathered 2 exactly identical records for each of the 14 videos
# then just keep only one of each unique records
df['duplicates'] = df['video_id'].duplicated(keep='last')
df = df[df['duplicates'] == False]
df.drop(columns=['duplicates'], inplace=True)
# confirm if duplicates are removed
df.shape[0]
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# 1118

# %%
# finally, see what the cleaned-up dataframe looks like
df.head(3)
# Out:
#       video_id                                        video_title upload_date  \
# 0  CQPLo8hECWg  Twice Baked Potatoes -- How to Make Fancy Stuf...  2012-12-15
# 1  TsrTU3CJn2c  Irish Shepherd's Pie - Classic Shepherd Pie fo...  2012-03-05
# 2  wRtGM3f-UBc             How to Flip Food in a Pan Like a Chef!  2012-10-04
#
#    view_count  like_count  comment_count  upload_year  upload_month  \
# 0     4194592       47213           1950         2012            12
# 1     2730866       44230           2843         2012             3
# 2     2764323       17837           1382         2012            10
#
#    upload_day upload_yearmonth
# 0          15          2012-12
# 1           5          2012-03
# 2           4          2012-10

# %%
import numpy as np
df['month_diff'] = round((np.datetime64('2022-03-01') - pd.to_datetime(df['upload_yearmonth'].astype(str)))/np.timedelta64(1, 'M'), 0)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
counts_sum = df.groupby(['upload_yearmonth', 'month_diff']).sum()[['view_count', 'like_count', 'comment_count']].reset_index()
counts_sum['upload_yearmonth'] = counts_sum['upload_yearmonth'].astype(str)
for col in list(counts_sum.columns.values)[2:5]:
        new_col = col + '_month_normalised'
        counts_sum[new_col] = counts_sum[col] / counts_sum['month_diff']

counts_sum.head(3)
# Out:
#   upload_yearmonth  month_diff  view_count  like_count  comment_count  \
# 0          2012-01       122.0     6046941       96394           8131
# 1          2012-02       121.0    16977317      210647          11742
# 2          2012-03       120.0     9596025      169435          10616
#
#    view_count_month_normalised  like_count_month_normalised  \
# 0                 49565.090164                   790.114754
# 1                140308.404959                  1740.884298
# 2                 79966.875000                  1411.958333
#
#    comment_count_month_normalised
# 0                       66.647541
# 1                       97.041322
# 2                       88.466667

# %%
import plotly.express as px

for col in counts_sum.columns.values[2:5]:
    fig = px.bar(counts_sum, x='upload_yearmonth', y=col)
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="4d3d544b-051b-4eb0-a27f-451873e83bf9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d3d544b-051b-4eb0-a27f-451873e83bf9")) {                    Plotly.newPlot(                        "4d3d544b-051b-4eb0-a27f-451873e83bf9",                        [{"alignmentgroup":"True","hovertemplate":"upload_yearmonth=%{x}<br>view_count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2012-01","2012-02","2012-03","2012-04","2012-05","2012-06","2012-07","2012-08","2012-09","2012-10","2012-11","2012-12","2013-01","2013-02","2013-03","2013-04","2013-05","2013-06","2013-07","2013-08","2013-09","2013-10","2013-11","2013-12","2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12","2015-01","2015-02","2015-03","2015-04","2015-05","2015-06","2015-07","2015-08","2015-09","2015-10","2015-11","2015-12","2016-01","2016-02","2016-03","2016-04","2016-05","2016-06","2016-07","2016-08","2016-09","2016-10","2016-11","2016-12","2017-01","2017-02","2017-03","2017-04","2017-05","2017-06","2017-07","2017-08","2017-09","2017-10","2017-11","2017-12","2018-01","2018-02","2018-03","2018-04","2018-05","2018-06","2018-07","2018-08","2018-09","2018-10","2018-11","2018-12","2019-01","2019-02","2019-03","2019-04","2019-05","2019-06","2019-07","2019-08","2019-09","2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03"],"xaxis":"x","y":[6046941,16977317,9596025,9023302,8362327,7021112,5093289,2842971,2804122,6260968,10783193,7428235,7623962,5368196,9507082,21228400,4134203,11059682,7131046,7203279,6067407,10544228,11495392,5257857,6056247,7535138,5465541,5962296,5171916,4937691,2706773,7655412,3468273,9659543,6106452,6041231,6938149,9938393,12722974,6409059,6668426,12203355,10309563,4702935,5275823,7929151,2126596,7576905,5150749,6910914,6472081,6755277,3115878,7863092,8721446,3766203,5676048,8485986,2641191,4525684,8245344,7854748,7048131,12954284,6232238,6345870,6997801,4576933,5338627,5549157,4115101,4472745,7185749,3997217,3453946,2359247,4366693,4347315,2884477,3914299,7125724,4132402,3368333,2456812,5681799,7096357,6312985,3958393,3102881,3876777,3090085,3143597,2657378,5308900,4708195,1321833,3300177,3350578,3553940,2125327,2912530,2861014,3498546,2759715,2216810,2485774,1328946,2607867,2201136,2390812,1988623,3208857,1785489,2132650,1639196,2316211,1600416,2864040,2576718,3878854,4732117,2451206,530099],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a2070c38-b196-4b36-9281-69fffb4cad62" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2070c38-b196-4b36-9281-69fffb4cad62")) {                    Plotly.newPlot(                        "a2070c38-b196-4b36-9281-69fffb4cad62",                        [{"alignmentgroup":"True","hovertemplate":"upload_yearmonth=%{x}<br>like_count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2012-01","2012-02","2012-03","2012-04","2012-05","2012-06","2012-07","2012-08","2012-09","2012-10","2012-11","2012-12","2013-01","2013-02","2013-03","2013-04","2013-05","2013-06","2013-07","2013-08","2013-09","2013-10","2013-11","2013-12","2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12","2015-01","2015-02","2015-03","2015-04","2015-05","2015-06","2015-07","2015-08","2015-09","2015-10","2015-11","2015-12","2016-01","2016-02","2016-03","2016-04","2016-05","2016-06","2016-07","2016-08","2016-09","2016-10","2016-11","2016-12","2017-01","2017-02","2017-03","2017-04","2017-05","2017-06","2017-07","2017-08","2017-09","2017-10","2017-11","2017-12","2018-01","2018-02","2018-03","2018-04","2018-05","2018-06","2018-07","2018-08","2018-09","2018-10","2018-11","2018-12","2019-01","2019-02","2019-03","2019-04","2019-05","2019-06","2019-07","2019-08","2019-09","2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03"],"xaxis":"x","y":[96394,210647,169435,124481,125887,110364,91442,56425,59726,91639,226819,108271,140379,108151,191139,342017,92406,173789,142785,139558,104376,208819,156070,113397,119969,141637,93039,110717,93062,85644,57329,157664,84295,206128,112624,111838,142643,217265,234463,158090,135447,271144,194980,103345,109956,174572,56299,188414,116564,179213,145188,136357,55420,197825,173792,94336,149514,223140,66940,90156,193345,184721,187829,275074,153541,144423,175055,112277,132552,161837,111197,110585,176624,116299,103711,71717,143049,113444,84649,113187,196939,128578,96211,73824,178831,220071,196676,119968,114381,137871,111035,113737,87904,177202,165263,49197,128801,111364,144487,84420,116462,112600,145423,138683,98518,117945,61522,114707,103382,110822,93125,144346,91378,85455,78843,102135,71655,119680,82739,114517,125758,93508,28268],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"typ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a7c4c51e-7e1c-4332-bd19-0a76d175c0e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7c4c51e-7e1c-4332-bd19-0a76d175c0e9")) {                    Plotly.newPlot(                        "a7c4c51e-7e1c-4332-bd19-0a76d175c0e9",                        [{"alignmentgroup":"True","hovertemplate":"upload_yearmonth=%{x}<br>comment_count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2012-01","2012-02","2012-03","2012-04","2012-05","2012-06","2012-07","2012-08","2012-09","2012-10","2012-11","2012-12","2013-01","2013-02","2013-03","2013-04","2013-05","2013-06","2013-07","2013-08","2013-09","2013-10","2013-11","2013-12","2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12","2015-01","2015-02","2015-03","2015-04","2015-05","2015-06","2015-07","2015-08","2015-09","2015-10","2015-11","2015-12","2016-01","2016-02","2016-03","2016-04","2016-05","2016-06","2016-07","2016-08","2016-09","2016-10","2016-11","2016-12","2017-01","2017-02","2017-03","2017-04","2017-05","2017-06","2017-07","2017-08","2017-09","2017-10","2017-11","2017-12","2018-01","2018-02","2018-03","2018-04","2018-05","2018-06","2018-07","2018-08","2018-09","2018-10","2018-11","2018-12","2019-01","2019-02","2019-03","2019-04","2019-05","2019-06","2019-07","2019-08","2019-09","2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03"],"xaxis":"x","y":[8131,11742,10616,7167,8076,7105,6906,5671,5185,6969,10906,6427,8646,6406,9093,17250,5237,9806,9071,8444,7520,12240,9224,6279,6090,6833,5454,6613,5193,3670,3749,8355,6099,12322,6630,6970,7160,9893,11468,5568,6424,10346,9267,6332,6001,8856,2905,8667,5692,8579,9075,7536,3091,5584,4126,3244,5880,3069,1223,1898,2866,4135,6712,4647,6830,7641,10026,6671,7995,10564,6947,7567,12407,8153,7844,4203,7843,6332,6320,7371,10654,7881,5164,4030,10219,10633,11902,7493,6186,6872,6564,6821,6310,9755,10978,3381,9284,6800,9989,4997,6383,6858,8736,8117,6365,6959,3901,6844,6838,6781,5876,10063,5660,4976,5317,6349,5410,5636,4309,5527,6507,4956,1434],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.11111111 ...

# %%
for col in counts_sum.columns.values[5:8]:
    fig = px.bar(counts_sum, x='upload_yearmonth', y=col)
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f08da82a-2154-4c22-862c-738ee5334c33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f08da82a-2154-4c22-862c-738ee5334c33")) {                    Plotly.newPlot(                        "f08da82a-2154-4c22-862c-738ee5334c33",                        [{"alignmentgroup":"True","hovertemplate":"upload_yearmonth=%{x}<br>view_count_month_normalised=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2012-01","2012-02","2012-03","2012-04","2012-05","2012-06","2012-07","2012-08","2012-09","2012-10","2012-11","2012-12","2013-01","2013-02","2013-03","2013-04","2013-05","2013-06","2013-07","2013-08","2013-09","2013-10","2013-11","2013-12","2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12","2015-01","2015-02","2015-03","2015-04","2015-05","2015-06","2015-07","2015-08","2015-09","2015-10","2015-11","2015-12","2016-01","2016-02","2016-03","2016-04","2016-05","2016-06","2016-07","2016-08","2016-09","2016-10","2016-11","2016-12","2017-01","2017-02","2017-03","2017-04","2017-05","2017-06","2017-07","2017-08","2017-09","2017-10","2017-11","2017-12","2018-01","2018-02","2018-03","2018-04","2018-05","2018-06","2018-07","2018-08","2018-09","2018-10","2018-11","2018-12","2019-01","2019-02","2019-03","2019-04","2019-05","2019-06","2019-07","2019-08","2019-09","2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03"],"xaxis":"x","y":[49565.09016393442,140308.40495867768,79966.875,75826.06722689075,70867.17796610169,60009.50427350427,43907.66379310345,24721.486956521738,24597.56140350877,55406.79646017699,96278.50892857143,66921.03603603604,69308.74545454545,49249.50458715596,88028.53703703704,198396.261682243,39001.91509433962,105330.30476190476,68567.75,69934.74757281554,59484.382352941175,104398.29702970297,114953.92,53109.666666666664,61798.43877551021,77681.8350515464,56932.71875,62761.01052631579,55020.382978723406,53093.45161290323,29421.445652173912,84125.40659340659,38536.36666666667,108534.19101123596,69391.5,69439.4367816092,80676.1511627907,116922.27058823529,151463.97619047618,77217.578313253,81322.26829268293,150658.7037037037,128869.5375,59530.82278481012,67638.7564102564,102975.98701298701,27981.526315789473,101025.4,69604.71621621621,94670.05479452055,89890.01388888889,95144.74647887323,44512.54285714286,113957.85507246378,128256.55882352941,56211.985074626864,86000.72727272728,130553.63076923077,41268.609375,71836.25396825396,132989.4193548387,128766.3606557377,117468.85,219564.13559322033,107452.37931034483,111331.05263157895,124960.73214285714,83216.96363636364,98863.46296296296,104701.07547169812,79136.55769230769,87700.88235294117,143714.98,81575.85714285714,71957.20833333333,50196.744680851065,94928.10869565218,96607.0,65556.29545454546,91030.20930232559,169660.09523809524,100790.29268292683,84208.325,62995.179487179485,149521.02631578947,191793.43243243243,175360.69444444444,113096.94285714286,91261.20588235294,117478.09090909091,96565.15625,101406.35483870968,88579.26666666666,183065.5172413793,168149.82142857142,48956.77777777778,126929.88461538461,134023.12,148080.83333333334,92405.52173913043,132387.72727272726,136238.7619047619,174927.3,145248.15789473685,123156.11111111111,146222.0,83059.125,173857.8,157224.0,183908.61538461538,165718.58333333334,291714.2727272727,178548.9,236961.11111111112,20489 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b2b459f5-6af4-4ae0-b8a8-171f151938da" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2b459f5-6af4-4ae0-b8a8-171f151938da")) {                    Plotly.newPlot(                        "b2b459f5-6af4-4ae0-b8a8-171f151938da",                        [{"alignmentgroup":"True","hovertemplate":"upload_yearmonth=%{x}<br>like_count_month_normalised=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2012-01","2012-02","2012-03","2012-04","2012-05","2012-06","2012-07","2012-08","2012-09","2012-10","2012-11","2012-12","2013-01","2013-02","2013-03","2013-04","2013-05","2013-06","2013-07","2013-08","2013-09","2013-10","2013-11","2013-12","2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12","2015-01","2015-02","2015-03","2015-04","2015-05","2015-06","2015-07","2015-08","2015-09","2015-10","2015-11","2015-12","2016-01","2016-02","2016-03","2016-04","2016-05","2016-06","2016-07","2016-08","2016-09","2016-10","2016-11","2016-12","2017-01","2017-02","2017-03","2017-04","2017-05","2017-06","2017-07","2017-08","2017-09","2017-10","2017-11","2017-12","2018-01","2018-02","2018-03","2018-04","2018-05","2018-06","2018-07","2018-08","2018-09","2018-10","2018-11","2018-12","2019-01","2019-02","2019-03","2019-04","2019-05","2019-06","2019-07","2019-08","2019-09","2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03"],"xaxis":"x","y":[790.1147540983607,1740.8842975206612,1411.9583333333333,1046.0588235294117,1066.8389830508474,943.2820512820513,788.2931034482758,490.6521739130435,523.9122807017544,810.9646017699115,2025.169642857143,975.4144144144144,1276.1727272727273,992.2110091743119,1769.8055555555557,3196.4205607476633,871.7547169811321,1655.1333333333334,1372.9326923076924,1354.9320388349515,1023.2941176470588,2067.5148514851485,1560.7,1145.4242424242425,1224.1734693877552,1460.1752577319587,969.15625,1165.4421052631578,990.0212765957447,920.9032258064516,623.1413043478261,1732.5714285714287,936.6111111111111,2316.044943820225,1279.8181818181818,1285.4942528735633,1658.639534883721,2556.0588235294117,2791.2261904761904,1904.698795180723,1651.7926829268292,3347.456790123457,2437.25,1308.1645569620252,1409.6923076923076,2267.1688311688313,740.7763157894736,2512.1866666666665,1575.1891891891892,2454.972602739726,2016.5,1920.5211267605634,791.7142857142857,2867.0289855072465,2555.764705882353,1408.0,2265.3636363636365,3432.923076923077,1045.9375,1431.047619047619,3118.467741935484,3028.2131147540986,3130.483333333333,4662.271186440678,2647.2586206896553,2533.7368421052633,3125.9821428571427,2041.4,2454.6666666666665,3053.5283018867926,2138.403846153846,2168.3333333333335,3532.48,2373.4489795918366,2160.6458333333335,1525.8936170212767,3109.7608695652175,2520.9777777777776,1923.840909090909,2632.2558139534885,4689.023809523809,3136.048780487805,2405.275,1892.923076923077,4706.078947368421,5947.864864864865,5463.222222222223,3427.657142857143,3364.1470588235293,4177.909090909091,3469.84375,3668.935483870968,2930.133333333333,6110.413793103448,5902.25,1822.111111111111,4953.884615384615,4454.56,6020.291666666667,3670.4347826086955,5293.727272727273,5361.9047619047615,7271.15,7299.105263157895,5473.222222222223,6937.941176470588,3845.125,7647.133333333333,7384.428571428572,8524.76923076923,7760.416666666667,13122.363636363636,91 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6157afc3-7be9-42f5-9d1b-63145800c41f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6157afc3-7be9-42f5-9d1b-63145800c41f")) {                    Plotly.newPlot(                        "6157afc3-7be9-42f5-9d1b-63145800c41f",                        [{"alignmentgroup":"True","hovertemplate":"upload_yearmonth=%{x}<br>comment_count_month_normalised=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2012-01","2012-02","2012-03","2012-04","2012-05","2012-06","2012-07","2012-08","2012-09","2012-10","2012-11","2012-12","2013-01","2013-02","2013-03","2013-04","2013-05","2013-06","2013-07","2013-08","2013-09","2013-10","2013-11","2013-12","2014-01","2014-02","2014-03","2014-04","2014-05","2014-06","2014-07","2014-08","2014-09","2014-10","2014-11","2014-12","2015-01","2015-02","2015-03","2015-04","2015-05","2015-06","2015-07","2015-08","2015-09","2015-10","2015-11","2015-12","2016-01","2016-02","2016-03","2016-04","2016-05","2016-06","2016-07","2016-08","2016-09","2016-10","2016-11","2016-12","2017-01","2017-02","2017-03","2017-04","2017-05","2017-06","2017-07","2017-08","2017-09","2017-10","2017-11","2017-12","2018-01","2018-02","2018-03","2018-04","2018-05","2018-06","2018-07","2018-08","2018-09","2018-10","2018-11","2018-12","2019-01","2019-02","2019-03","2019-04","2019-05","2019-06","2019-07","2019-08","2019-09","2019-10","2019-11","2019-12","2020-01","2020-02","2020-03","2020-04","2020-05","2020-06","2020-07","2020-08","2020-09","2020-10","2020-11","2020-12","2021-01","2021-02","2021-03","2021-04","2021-05","2021-06","2021-07","2021-08","2021-09","2021-10","2021-11","2021-12","2022-01","2022-02","2022-03"],"xaxis":"x","y":[66.64754098360656,97.04132231404958,88.46666666666667,60.226890756302524,68.44067796610169,60.72649572649573,59.53448275862069,49.31304347826087,45.48245614035088,61.67256637168141,97.375,57.9009009009009,78.6,58.77064220183486,84.19444444444444,161.21495327102804,49.405660377358494,93.39047619047619,87.22115384615384,81.98058252427184,73.72549019607843,121.18811881188118,92.24,63.42424242424242,62.142857142857146,70.44329896907216,56.8125,69.61052631578947,55.244680851063826,39.46236559139785,40.75,91.81318681318682,67.76666666666667,138.4494382022472,75.3409090909091,80.11494252873563,83.25581395348837,116.38823529411765,136.52380952380952,67.08433734939759,78.34146341463415,127.72839506172839,115.8375,80.15189873417721,76.93589743589743,115.01298701298701,38.223684210526315,115.56,76.91891891891892,117.52054794520548,126.04166666666667,106.14084507042253,44.15714285714286,80.92753623188406,60.6764705882353,48.417910447761194,89.0909090909091,47.215384615384615,19.109375,30.126984126984127,46.225806451612904,67.78688524590164,111.86666666666666,78.76271186440678,117.75862068965517,134.05263157894737,179.03571428571428,121.2909090909091,148.05555555555554,199.32075471698113,133.59615384615384,148.37254901960785,248.14,166.3877551020408,163.41666666666666,89.42553191489361,170.5,140.7111111111111,143.63636363636363,171.41860465116278,253.66666666666666,192.21951219512195,129.1,103.33333333333333,268.92105263157896,287.3783783783784,330.6111111111111,214.0857142857143,181.94117647058823,208.24242424242425,205.125,220.03225806451613,210.33333333333334,336.37931034482756,392.07142857142856,125.22222222222223,357.0769230769231,272.0,416.2083333333333,217.2608695652174,290.1363636363636,326.57142857142856,436.8,427.2105263157895,353.6111111111111,409.3529411764706,243.8125,456.26666666666665,488.42857142857144,521.6153846153846,489.6666666666667,914.8181818181819,566.0,552.8888888888889,664.625,907 ...
